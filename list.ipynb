# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/python-internship-210502026/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = [1, 'apple', 3.14, 3+5j ]

print(type(l))
# Out:
# <class 'list'>

# %%
l = [1, 3, 5, 7, 8, 9]

print(l[-3])
print(l[4])
# Out:
# 7
# 8

# %%
l = [1, 3, 5, 7, 8, 9]

l[:] #[1, 3, 5, 7, 8, 9]

l[-2:] #[8, 9]

l[:-2] #[1, 3, 5, 7]

l[-2::-3]

l[-2:-4:-3]
# Out:
# [8]

# %%
l = [1, 'aptech', 3+3j, 3.14]

#type(l) #<class 'list'>

#print(type(l[2])) #<class 'complex'>

#type(l[0]) #<class 'int'>

type(l[3]) #<class 'float'>  #Heterogenous
# Out:
# float

# %%
li = "Aptech Learning"
l = list(li)
l[2] = 'T'
l[9] = 'A'
l
# Out:
# ['A', 'p', 'T', 'e', 'c', 'h', ' ', 'L', 'e', 'A', 'r', 'n', 'i', 'n', 'g']

# %%
li = "Aptech Learning"
l = ''
print(l.join(li[:2]+li[2].upper()+li[3:9]+li[9].upper()+li[10:]))
# Out:
# ApTech LeArning

# %%
l = [1, 3, 5, 7, 8, 9]
print(len(l))

l.append(10)
print(l)

l.insert(1, 2)
print(l)

popitem = l.pop()
print(popitem)
print(l)

l.remove(1)
print(l)

del l[1]
print(l)

#del l
#print(l)

l.clear()
print(l)
# Out:
# 6
# [1, 3, 5, 7, 8, 9, 10]
# [1, 2, 3, 5, 7, 8, 9, 10]
# 10
# [1, 2, 3, 5, 7, 8, 9]
# [2, 3, 5, 7, 8, 9]
# [2, 5, 7, 8, 9]
# []

# %%
l = 'Jay Hind Bharat'
l1 = l.split()
l1.insert(0, 'JAY')
l1.remove('Jay')
l1.insert(2, "BHARAT")
l1.remove('Bharat')

print("Number of words : ", len(l1))
l = "".join(l1[0]+" "+l1[1]+" "+l1[2])
print(l)
# Out:
# Number of words :  3
# JAY Hind BHARAT

# %%
t = (1, 3, 5, 7, 8, 9)

print(type(t))

#t[0] = 2

t = list(t)
t[2] = 6
t = tuple(t)

#del t[0]

#del t

#slicing is also there tuple

t[:]

t[::2]

t[::-1]

#print(t)
# Out:
# <class 'tuple'>
# (9, 8, 7, 6, 3, 1)
